# %%
import pandas as pd
import plotly.express as px
import os

# %%
time_df = pd.read_csv("/Users/nick/Cole Trapnell's Lab Dropbox/Nick Lammers/Nick/morphseq/seq_data/emb_projections/latent_projections/bead_exp_linear_20250606/time_predictions.csv", index_col=0)

# %%
from src.functions.plot_functions import format_2d_plotly

fig = px.scatter(time_df, y="mean_nn_time", x="pseudostage", color="timepoint", symbol="expt", color_continuous_scale="viridis",
                range_color=(0, 100) )
fig = format_2d_plotly(fig, axis_labels=["psuedostage (Hooke-based)", "nn times (projection-based)"], theme="light", marker_size=8)
fig.show()

fig.write_html("/Users/nick/Cole Trapnell's Lab Dropbox/Nick Lammers/Nick/morphseq/results/20250615_staging/nn_vs_pseudostage.html")
fig.write_image("/Users/nick/Cole Trapnell's Lab Dropbox/Nick Lammers/Nick/morphseq/results/20250615_staging/nn_vs_pseudostage.png")

# %%
time_df.head()
